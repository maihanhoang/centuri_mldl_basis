# %% [markdown]
# # The predictive modeling pipeline
#
# Tabular data exploration
# * [📝 Exercise M1.01](notebooks/M1_01_tabular_data_exploration.ipynb)
#
# Fitting a scikit-learn model on numerical data
# * [📝 Exercise M1.02](notebooks/M1_02_numerical_pipeline.ipynb)
# * [📝 Exercise M1.03](notebooks/M1_03_numerical_pipeline.ipynb)
#
# Handling categorical data
# * [📝 Exercise M1.04](notebooks/M1_04_categorical_pipeline.ipynb)
# * [📝 Exercise M1.05](notebooks/M1_05_categorical_pipeline.ipynb)
#
# Validation and learning curves
# * [📝 Exercise M2.01](notebooks/M2_01_cross_validation.ipynb)
#
# Manual tuning
# * [📝 Exercise M3.01](notebooks/M3_01_parameter_tuning.ipynb)
#
# Automated tuning
# * [📝 Exercise M3.02](notebooks/M3_02_parameter_tuning.ipynb)
#
# # Linear models
#
# Intuitions on linear models
# * [📝 Exercise M4.01](notebooks/M4_01_linear_models.ipynb)
#
# Non-linear feature engineering for linear models
# * [📝 Exercise M4.02](notebooks/M2_02_linear_models.ipynb)
# * [📝 Exercise M4.03](notebooks/M4_03_linear_models.ipynb)
#
# Regularization in linear model
# * [📝 Exercise M4.04](notebooks/M4_04_linear_models.ipynb)
#
# # Decision tree models
#
# Decision tree in classification
# * [📝 Exercise M5.01](notebooks/M5_01_trees.ipynb)
#
# Decision tree in regression
# * [📝 Exercise M5.02](notebooks/M5_02_trees.ipynb)
#
# # Ensemble of models
#
# Ensemble method using bootstrapping
# * [📝 Exercise M6.01](notebooks/M6_01_ensemble.ipynb)
# * [📝 Exercise M6.02](notebooks/M6_02_ensemble.ipynb)
#
# Ensemble based on boosting
# * [📝 Exercise M6.03](notebooks/M6_03_ensemble.ipynb)
#
# Hyperparameter tuning with ensemble methods
# * [📝 Exercise M6.04](notebooks/M6_04_ensemble.ipynb)
#
# # Evaluating model performance
#
# Comparing a model with simple baselines
# * [📝 Exercise M7.01](notebooks/M7_01_cross_validation.ipynb)
#
# Classification metrics
# * [📝 Exercise M7.02](notebooks/M7_02_metrics.ipynb)
#
# Regression metrics
# * [📝 Exercise M7.03](notebooks/M7_03_metrics.ipynb)
